# %%
import pandas as pd
import yfinance as yf
from sqlalchemy import create_engine

# %%
engine = create_engine("sqlite:///Stockpricedata.db")

# %%
#getting financial info from microsoft
obj = yf.Ticker("MSFT")

# %%
#getting table of stocks of varoius companies from wikipedia
dow= pd.read_html("https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average")

# %%
dow
# Out:
# [                                                   0  \
#  0  Historical logarithmic graph of the DJIA from ...
#  1                                         Foundation
#  2                                           Operator
#  3                                          Exchanges
#  4                                     Trading symbol
#  5                                       Constituents
#  6                                               Type
#  7                                         Market cap
#  8                                   Weighting method
#  9                                            Website
#
#                                                     1
#  0  Historical logarithmic graph of the DJIA from ...
#  1  February 16, 1885; 137 years ago[1]May 26, 189...
#  2                              S&P Dow Jones Indices
#  3                      New York Stock ExchangeNASDAQ
#  4                                  ^DJI$INDU.DJIDJIA
#  5                                                 30
#  6                                          Large cap
#  7           US$10.35 trillion(as of June 3, 2022)[3]
#  8                               Price-weighted index
#  9  us.spindices.com/indices/equity/dow-jones-indu...  ,
#                       Company Exchange Symbol                        Industry  \
#  0                         3M     NYSE    MMM                    Conglomerate
#  1           American Express     NYSE    AXP              Financial services
#  2                      Amgen   NASDAQ   AMGN               Biopharmaceutical
#  3                      Apple   NASDAQ   AAPL          Information technology
#  4                     Boeing     NYSE     BA           Aerospace and defense
#  5                Caterpillar     NYSE    CAT         Construction and Mining
#  6                    Chevron     NYSE    CVX              Petroleum industry
#  7                      Cisco   NASDAQ   CSCO          Information technology
#  8                  Coca-Cola     NYSE     KO                  Drink industry
#  9                     Disney     NYSE    DIS  Broadcasting and entertainment
#  10                       Dow     NYSE    DOW               Chemical industry
#  11             Goldman Sachs     NYSE     GS              Financial services
#  12                Home Depot     NYSE     HD                Home Improvement
#  13                 Honeywell   NASDAQ    HON                    Conglomerate
#  14                       IBM     NYSE    IBM          Information technology
#  15                     Intel   NASDAQ   INTC          Semiconductor industry
#  16         Johnson & Johnson     NYSE    JNJ         Pharmaceutical industry
#  17            JPMorgan Chase     NYSE    JPM              Financial services
#  18                McDonald's     NYSE    MCD                   Food industry
#  19                     Merck     NYSE    MRK         Pharmaceutical industry
#  20                 Microsoft   NASDAQ   MSFT          Information technology
#  21                      Nike     NYSE    NKE               Clothing industry
#  22          Procter & Gamble     NYSE     PG      Fast-moving consumer goods
#  23                Salesforce     NYSE    CRM          Information technology
#  24                 Travelers     NYSE    TRV                       Insurance
#  25              UnitedHealth     NYSE    UNH             Managed health care
#  26                   Verizon     NYSE     VZ     Telecommunications industry
#  27                      Visa     NYSE      V              Financial services
#  28  Walgreens Boots Alliance   NASDAQ    WBA                       Retailing
#  29                   Walmart     NYSE    WMT                       Retailing
#
#      Date added                                              Notes  \
#  0   1976-08-09              As Minnesota Mining and Manufacturing
#  1   1982-08-30                                                NaN
#  2   2020-08-31                                                NaN
#  3   2015-03-19                                                NaN
#  4   1987-03-12                                                NaN
#  5   1991-05-06                                                NaN
#  6   2008-02-19                      Also 1930-07-18 to 1999-11-01
#  7   2009-06-08                                                NaN
#  8   1987-03-12                      Also 1932-05-26 to 1935-11-20
#  9   1991-05-06                                                NaN
#  10  2019-04-02                                                NaN
#  11  2013-09-20                                                NaN
#  12  1999-11-01                                                NaN
#  13  2020-08-31  Also 1925-12-07 to 2008-02-19 under various na...
#  14  1979-06-29                      Also 1932-05-26 to 1939-03-04
#  15  1999-11-01                                                NaN
#  16  1997-03-17                                                NaN
#  17  1991-05-06                                                NaN
#  18  1985-10-30                                                NaN
#  19  1979-06-29                                                NaN
#  20  1999-11-01                                                NaN
#  21  2013-09-20                                                NaN
#  22  1932-05-26                                                NaN
#  23  2020-08-31                                                NaN
#  24  2009-06-08                                                NaN
#  25  2012-09-24                                                NaN
#  26  2004-04-08                                                NaN
#  27  2013-09-20                                                NaN
#  28  2018-06-26                                                NaN
#  29  1997-03-17                                                NaN
#
#     Index weighting
#  0            2.88%
#  1            3.56%
#  2            4.88%
#  3            3.15%
#  4            3.40%
#  5            4.19%
#  6            3.05%
#  7            1.00%
#  8            1.28%
#  9            2.32%
#  10           1.32%
#  11           6.22%
#  12           5.90%
#  13           3.71%
#  14           2.69%
#  15           0.91%
#  16           3.60%
#  17           2.45%
#  18           4.89%
#  19           1.65%
#  20           5.43%
#  21           2.48%
#  22           3.15%
#  23           3.38%
#  24           3.38%
#  25          10.14%
#  26           0.97%
#  27           4.06%
#  28           0.88%
#  29           3.04%  ,
#       Year  Closing Value Net Change % Change
#  0    1896          40.45      −0.49    −1.20
#  1    1897          49.41      +8.96   +22.15
#  2    1898          60.52     +11.11   +22.49
#  3    1899          66.08      +5.56    +9.19
#  4    1900          70.71      +4.63    +7.01
#  ..    ...            ...        ...      ...
#  121  2017       24719.22   +4956.62   +25.08
#  122  2018       23327.46  −1,391.76    −5.63
#  123  2019       28538.44   +5210.98   +22.34
#  124  2020       30606.48   +2068.04    +7.25
#  125  2021       36338.30   +5731.82   +18.73
#
#  [126 rows x 4 columns],
#             Date    Divisor  $1 change (points)
#  0    2021-11-04   0.151728            6.590762
#  1    2021-06-03   0.151885            6.583921
#  2    2020-08-31   0.151987            6.579507
#  3    2020-04-03   0.145798            6.858799
#  4    2019-04-02   0.147446            6.782159
#  ..          ...        ...                 ...
#  235  1929-01-08  12.110000            0.082576
#  236  1928-12-26  13.920000            0.071839
#  237  1928-12-13  14.650000            0.068259
#  238  1928-11-05  16.020000            0.062422
#  239  1928-10-01  16.670000            0.059988
#
#  [240 rows x 3 columns],
#    .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vteComponents of the Dow Jones Industrial Average  \
#  0  3M American Express Amgen Apple Boeing Caterpi...
#
#    .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vteComponents of the Dow Jones Industrial Average.1
#  0  3M American Express Amgen Apple Boeing Caterpi...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ,
#    vteMajor North and South American stock market indices  \
#  0                                      United States
#  1                                             Canada
#  2                                             Mexico
#  3                                           Colombia
#  4                                             Brazil
#  5                                              Chile
#  6                                          Argentina
#  7                                               Peru
#
#    vteMajor North and South American stock market indices.1
#  0  Dow Jones Industrial Average Dow Jones Transpo...
#  1                 S&P/TSX 60 S&P/TSX Composite Index
#  2                   Indice de Precios y Cotizaciones
#  3  COLCAP Indice General de la Bolsa de Valores d...
#  4                                     Índice Bovespa
#  5             Índice de Precio Selectivo de Acciones
#  6                                             MERVAL
#  7                         S&P/BVL Peru General Index        ,
#                                           vteNews Corp  \
#  0                     Sister company: Fox Corporation
#  1   vteDow Jones & CompanyNational consumer produc...
#  2                              vteDow Jones & Company
#  3                          National consumer products
#  4                                 Enterprise products
#  5   vteHarperCollinsUnited States Avon Caedmon Ecc...
#  6                                    vteHarperCollins
#  7                                       United States
#  8                                      United Kingdom
#  9                                           Australia
#  10                                          Christian
#  11                                             Canada
#  12  vteNews Corp AustraliaNewspapersMetropolitan T...
#  13                             vteNews Corp Australia
#  14                                         Newspapers
#  15                                       Metropolitan
#  16                                           Regional
#  17                                         Queensland
#  18                                              Other
#  19  vteNews Corp Australia community newspapersNew...
#  20        vteNews Corp Australia community newspapers
#  21                                    NewsLocal (NSW)
#  22                                     Messenger (SA)
#  23                                        Quest (Qld)
#  24                                           Victoria
#  25                                         Television
#  26                              vteSky News Australia
#  27                                           Channels
#  28                                             Active
#  29                                            Defunct
#  30                                         Presenters
#  31                                            Current
#  32                                             Former
#  33                                        Programming
#  34                  vteSky News Australia programming
#  35                                            Current
#  36                                            Daytime
#  37                                          Primetime
#  38                                             Former
#  39                                            Daytime
#  40                                          Primetime
#  41                                          Magazines
#  42                                              Other
#  43                                     Formerholdings
#  44  vteNews UKNewspapers The Times The Sunday Time...
#  45                                         vteNews UK
#  46                                         Newspapers
#  47                                           Magazine
#  48                                              Radio
#  49                                         Television
#  50                                       Other assets
#  51      See also: 21st Century Fox · News Corporation
#
#                                         vteNews Corp.1
#  0                     Sister company: Fox Corporation
#  1   vteDow Jones & CompanyNational consumer produc...
#  2                              vteDow Jones & Company
#  3   Barron's Financial News Investor's Business Da...
#  4                Factiva S&P Dow Jones Indices (2.6%)
#  5   vteHarperCollinsUnited States Avon Caedmon Ecc...
#  6                                    vteHarperCollins
#  7   Avon Caedmon Ecco Harper Harper Perennial I Ca...
#  8   William Collins, Sons Collins Bartholomew The ...
#  9                                   Angus & Robertson
#  10  BibleGateway.com Thomas Nelson Women of Faith ...
#  11           Harlequin Enterprises Love Inspired Mira
#  12  vteNews Corp AustraliaNewspapersMetropolitan T...
#  13                             vteNews Corp Australia
#  14  Metropolitan The Australian The Daily Telegrap...
#  15  The Australian The Daily Telegraph (Sydney) He...
#  16  Queensland Balonne Beacon Bowen Independent Th...
#  17  Balonne Beacon Bowen Independent The Cairns Po...
#  18  The Coffs Coast Advocate The Daily Examiner Ge...
#  19  vteNews Corp Australia community newspapersNew...
#  20        vteNews Corp Australia community newspapers
#  21  Manly Daily North Shore Times Northern Distric...
#  22  News Review Leader Standard Eastern Courier Ea...
#  23                      South-West News Southern Star
#  24                        Leader Community Newspapers
#  25  vteSky News AustraliaChannelsActive Sky News L...
#  26                              vteSky News Australia
#  27  Active Sky News Live Sky News Extra Sky News W...
#  28  Sky News Live Sky News Extra Sky News Weather ...
#  29  Sky News Business Channel Sky News Election Ch...
#  30  Current Kieran Gilbert Ashleigh Gillon Vanessa...
#  31  Kieran Gilbert Ashleigh Gillon Vanessa Grimm S...
#  32  Samantha Armytage Helen Dalley Georgie Gardner...
#  33  vteSky News Australia programmingCurrentDaytim...
#  34                  vteSky News Australia programming
#  35  Daytime Agenda First Edition Weekend Outsiders...
#  36             Agenda First Edition Weekend Outsiders
#  37           Credlin Paul Murray Live The Bolt Report
#  38  Daytime Keneally and Cameron PVO NewsDay Pyne ...
#  39  Keneally and Cameron PVO NewsDay Pyne & Marles...
#  40  Credlin Keneally Friday Live Hinch Live Hadley...
#  41            Big League GQ Australia Vogue Australia
#  42  Brisbane Broncos (69%) Foxtel (65%) HT&E (15%)...
#  43  Australian Associated Press (47%) ADS (Adelaid...
#  44  vteNews UKNewspapers The Times The Sunday Time...
#  45                                         vteNews UK
#  46                 The Times The Sunday Times The Sun
#  47                      The Times Literary Supplement
#  48  Wireless Group TalkRadio Talksport Times Radio...
#  49                                             TalkTV
#  50  Move Realtor.com New York Post News America Ma...
#  51      See also: 21st Century Fox · News Corporation  ,
#         vteDow Jones & Company  \
#  0  National consumer products
#  1         Enterprise products
#
#                              vteDow Jones & Company.1
#  0  Barron's Financial News Investor's Business Da...
#  1               Factiva S&P Dow Jones Indices (2.6%)  ,
#    vteHarperCollins                                 vteHarperCollins.1
#  0    United States  Avon Caedmon Ecco Harper Harper Perennial I Ca...
#  1   United Kingdom  William Collins, Sons Collins Bartholomew The ...
#  2        Australia                                  Angus & Robertson
#  3        Christian  BibleGateway.com Thomas Nelson Women of Faith ...
#  4           Canada           Harlequin Enterprises Love Inspired Mira,
#                                 vteNews Corp Australia  \
#  0                                          Newspapers
#  1                                        Metropolitan
#  2                                            Regional
#  3                                          Queensland
#  4                                               Other
#  5   vteNews Corp Australia community newspapersNew...
#  6         vteNews Corp Australia community newspapers
#  7                                     NewsLocal (NSW)
#  8                                      Messenger (SA)
#  9                                         Quest (Qld)
#  10                                           Victoria
#  11                                         Television
#  12                              vteSky News Australia
#  13                                           Channels
#  14                                             Active
#  15                                            Defunct
#  16                                         Presenters
#  17                                            Current
#  18                                             Former
#  19                                        Programming
#  20                  vteSky News Australia programming
#  21                                            Current
#  22                                            Daytime
#  23                                          Primetime
#  24                                             Former
#  25                                            Daytime
#  26                                          Primetime
#  27                                          Magazines
#  28                                              Other
#  29                                     Formerholdings
#
#                               vteNews Corp Australia.1
#  0   Metropolitan The Australian The Daily Telegrap...
#  1   The Australian The Daily Telegraph (Sydney) He...
#  2   Queensland Balonne Beacon Bowen Independent Th...
#  3   Balonne Beacon Bowen Independent The Cairns Po...
#  4   The Coffs Coast Advocate The Daily Examiner Ge...
#  5   vteNews Corp Australia community newspapersNew...
#  6         vteNews Corp Australia community newspapers
#  7   Manly Daily North Shore Times Northern Distric...
#  8   News Review Leader Standard Eastern Courier Ea...
#  9                       South-West News Southern Star
#  10                        Leader Community Newspapers
#  11  vteSky News AustraliaChannelsActive Sky News L...
#  12                              vteSky News Australia
#  13  Active Sky News Live Sky News Extra Sky News W...
#  14  Sky News Live Sky News Extra Sky News Weather ...
#  15  Sky News Business Channel Sky News Election Ch...
#  16  Current Kieran Gilbert Ashleigh Gillon Vanessa...
#  17  Kieran Gilbert Ashleigh Gillon Vanessa Grimm S...
#  18  Samantha Armytage Helen Dalley Georgie Gardner...
#  19  vteSky News Australia programmingCurrentDaytim...
#  20                  vteSky News Australia programming
#  21  Daytime Agenda First Edition Weekend Outsiders...
#  22             Agenda First Edition Weekend Outsiders
#  23           Credlin Paul Murray Live The Bolt Report
#  24  Daytime Keneally and Cameron PVO NewsDay Pyne ...
#  25  Keneally and Cameron PVO NewsDay Pyne & Marles...
#  26  Credlin Keneally Friday Live Hinch Live Hadley...
#  27            Big League GQ Australia Vogue Australia
#  28  Brisbane Broncos (69%) Foxtel (65%) HT&E (15%)...
#  29  Australian Associated Press (47%) ADS (Adelaid...  ,
#                                                     0  \
#  0                                       Metropolitan
#  1                                           Regional
#  2                                         Queensland
#  3                                              Other
#  4  vteNews Corp Australia community newspapersNew...
#  5        vteNews Corp Australia community newspapers
#  6                                    NewsLocal (NSW)
#  7                                     Messenger (SA)
#  8                                        Quest (Qld)
#  9                                           Victoria
#
#                                                     1
#  0  The Australian The Daily Telegraph (Sydney) He...
#  1  Queensland Balonne Beacon Bowen Independent Th...
#  2  Balonne Beacon Bowen Independent The Cairns Po...
#  3  The Coffs Coast Advocate The Daily Examiner Ge...
#  4  vteNews Corp Australia community newspapersNew...
#  5        vteNews Corp Australia community newspapers
#  6  Manly Daily North Shore Times Northern Distric...
#  7  News Review Leader Standard Eastern Courier Ea...
#  8                      South-West News Southern Star
#  9                        Leader Community Newspapers  ,
#              0                                                  1
#  0  Queensland  Balonne Beacon Bowen Independent The Cairns Po...
#  1       Other  The Coffs Coast Advocate The Daily Examiner Ge...,
#    vteNews Corp Australia community newspapers  \
#  0                             NewsLocal (NSW)
#  1                              Messenger (SA)
#  2                                 Quest (Qld)
#  3                                    Victoria
#
#         vteNews Corp Australia community newspapers.1
#  0  Manly Daily North Shore Times Northern Distric...
#  1  News Review Leader Standard Eastern Courier Ea...
#  2                      South-West News Southern Star
#  3                        Leader Community Newspapers  ,
#                  vteSky News Australia  \
#  0                            Channels
#  1                              Active
#  2                             Defunct
#  3                          Presenters
#  4                             Current
#  5                              Former
#  6                         Programming
#  7   vteSky News Australia programming
#  8                             Current
#  9                             Daytime
#  10                          Primetime
#  11                             Former
#  12                            Daytime
#  13                          Primetime
#
#                                vteSky News Australia.1
#  0   Active Sky News Live Sky News Extra Sky News W...
#  1   Sky News Live Sky News Extra Sky News Weather ...
#  2   Sky News Business Channel Sky News Election Ch...
#  3   Current Kieran Gilbert Ashleigh Gillon Vanessa...
#  4   Kieran Gilbert Ashleigh Gillon Vanessa Grimm S...
#  5   Samantha Armytage Helen Dalley Georgie Gardner...
#  6   vteSky News Australia programmingCurrentDaytim...
#  7                   vteSky News Australia programming
#  8   Daytime Agenda First Edition Weekend Outsiders...
#  9              Agenda First Edition Weekend Outsiders
#  10           Credlin Paul Murray Live The Bolt Report
#  11  Daytime Keneally and Cameron PVO NewsDay Pyne ...
#  12  Keneally and Cameron PVO NewsDay Pyne & Marles...
#  13  Credlin Keneally Friday Live Hinch Live Hadley...  ,
#           0                                                  1
#  0   Active  Sky News Live Sky News Extra Sky News Weather ...
#  1  Defunct  Sky News Business Channel Sky News Election Ch...,
#           0                                                  1
#  0  Current  Kieran Gilbert Ashleigh Gillon Vanessa Grimm S...
#  1   Former  Samantha Armytage Helen Dalley Georgie Gardner...,
#    vteSky News Australia programming  \
#  0                           Current
#  1                           Daytime
#  2                         Primetime
#  3                            Former
#  4                           Daytime
#  5                         Primetime
#
#                   vteSky News Australia programming.1
#  0  Daytime Agenda First Edition Weekend Outsiders...
#  1             Agenda First Edition Weekend Outsiders
#  2           Credlin Paul Murray Live The Bolt Report
#  3  Daytime Keneally and Cameron PVO NewsDay Pyne ...
#  4  Keneally and Cameron PVO NewsDay Pyne & Marles...
#  5  Credlin Keneally Friday Live Hinch Live Hadley...  ,
#             0                                         1
#  0    Daytime    Agenda First Edition Weekend Outsiders
#  1  Primetime  Credlin Paul Murray Live The Bolt Report,
#             0                                                  1
#  0    Daytime  Keneally and Cameron PVO NewsDay Pyne & Marles...
#  1  Primetime  Credlin Keneally Friday Live Hinch Live Hadley...,
#     vteNews UK                                       vteNews UK.1
#  0  Newspapers                 The Times The Sunday Times The Sun
#  1    Magazine                      The Times Literary Supplement
#  2       Radio  Wireless Group TalkRadio Talksport Times Radio...
#  3  Television                                             TalkTV]

# %%
#subsetting the table for companies and their details
dow[1]
#storing the symbols column on the above table in a list
symbols = dow[1].Symbol.to_list()

# %%
symbols
# Out:
# ['MMM',
#  'AXP',
#  'AMGN',
#  'AAPL',
#  'BA',
#  'CAT',
#  'CVX',
#  'CSCO',
#  'KO',
#  'DIS',
#  'DOW',
#  'GS',
#  'HD',
#  'HON',
#  'IBM',
#  'INTC',
#  'JNJ',
#  'JPM',
#  'MCD',
#  'MRK',
#  'MSFT',
#  'NKE',
#  'PG',
#  'CRM',
#  'TRV',
#  'UNH',
#  'VZ',
#  'V',
#  'WBA',
#  'WMT']

# %%
infos = []

for symbol in symbols:
    inf = yf.Ticker(symbol).info
    infos.append(inf)

# %%
infos
# Out:
# [{'zip': '55144-1000',
#   'sector': 'Industrials',
#   'fullTimeEmployees': 95000,
#   'longBusinessSummary': '3M Company operates as a diversified technology company worldwide. It operates through four segments: Safety and Industrial; Transportation and Electronics; Health Care; and Consumer. The Safety and Industrial segment offers industrial abrasives and finishing for metalworking applications; autobody repair solutions; closure systems for personal hygiene products, masking, and packaging materials; electrical products and materials for construction and maintenance, power distribution, and electrical original equipment manufacturers; structural adhesives and tapes; respiratory, hearing, eye, and fall protection solutions; and natural and color-coated mineral granules for shingles. The Transportation and Electronics segment provides ceramic solutions; attachment tapes, films, sound, and temperature management for transportation vehicles; premium large format graphic films for advertising and fleet signage; light management films and electronics assembly solutions; packaging and interconnection solutions; and reflective signage for highway, and vehicle safety. The Healthcare segment offers food safety indicator solutions; health care procedure coding and reimbursement software; skin, wound care, and infection prevention products and solutions; dentistry and orthodontia solutions; and filtration and purification systems. The Consumer segment provides consumer bandages, braces, supports and consumer respirators; cleaning products for the home; retail abrasives, paint accessories, car care DIY products, picture hanging, and consumer air quality solutions; and stationery products. It offers its products through e-commerce and traditional wholesalers, retailers, jobbers, distributors, and dealers. The company was founded in 1902 and is based in St. Paul, Minnesota.',
#   'city': 'Saint Paul',
#   'phone': '651 733 1110',
#   'state': 'MN',
#   'country': 'United States',
#   'companyOfficers': [],
#   'website': 'https://www.3m.com',
#   'maxAge': 1,
#   'address1': '3M Center',
#   'industry': 'Conglomerates',
#   'ebitdaMargins': 0.20048,
#   'profitMargins': 0.18913999,
#   'grossMargins': 0.44353,
#   'operatingCashflow': 5673999872,
#   'revenueGrowth': -0.036,
#   'operatingMargins': 0.14645,
#   'ebitda': 6968999936,
#   'targetLowPrice': 110,
#   'recommendationKey': 'hold',
#   'grossProfits': 16579000000,
#   'freeCashflow': 2674249984,
#   'targetMedianPrice': 126,
#   'currentPrice': 125.79,
#   'earningsGrowth': 1.763,
#   'currentRatio': 1.561,
#   'returnOnAssets': 0.06737,
#   'numberOfAnalystOpinions': 18,
#   'targetMeanPrice': 129.73,
#   'debtToEquity': 117.484,
#   'returnOnEquity': 0.45931998,
#   'targetHighPrice': 210,
#   'totalCash': 3588999936,
#   'totalDebt': 16631000064,
#   'totalRevenue': 34761998336,
#   'totalCashPerShare': 6.493,
#   'financialCurrency': 'USD',
#   'revenuePerShare': 60.794,
#   'quickRatio': 0.871,
#   'recommendationMean': 3.2,
#   'exchange': 'NYQ',
#   'shortName': '3M Company',
#   'longName': '3M Company',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EDT',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-14400000',
#   'quoteType': 'EQUITY',
#   'symbol': 'MMM',
#   'messageBoardId': 'finmb_289194',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 2.39,
#   'beta3Year': None,
#   'enterpriseToEbitda': 11.924,
#   '52WeekChange': -0.3087322,
#   'morningStarRiskRating': None,
#   'forwardEps': 10.45,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 552742976,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 25.473,
#   'sharesShort': 14641662,
#   'sharesPercentSharesOut': 0.026400002,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1640908800,
#   'heldPercentInstitutions': 0.66955,
#   'netIncomeToCommon': 6575000064,
#   'trailingEps': 11.46,
#   'lastDividendValue': 1.49,
#   'SandP52WeekChange': -0.1638366,
#   'priceToBook': 4.93817,
#   'heldPercentInsiders': 0.00124,
#   'nextFiscalYearEnd': 1703980800,
#   'yield': None,
#   'mostRecentQuarter': 1664496000,
#   'shortRatio': 3.97,
#   'sharesShortPreviousMonthDate': 1663200000,
#   'floatShares': 552134898,
#   'beta': 0.986735,
#   'enterpriseValue': 83095257088,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1064880000,
#   'lastSplitFactor': '2:1',
#   'legalType': None,
#   'lastDividendDate': 1660867200,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 1.691,
#   'priceToSalesTrailing12Months': 2.0001595,
#   'dateShortInterest': 1665705600,
#   'pegRatio': 30.8,
#   'ytdReturn': None,
#   'forwardPE': 12.037321,
#   'lastCapGain': None,
#   'shortPercentOfFloat': 0.026500002,
#   'sharesShortPriorMonth': 19250841,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 126.6,
#   'regularMarketOpen': 126.1,
#   'twoHundredDayAverage': 140.1583,
#   'trailingAnnualDividendYield': 0.04699842,
#   'payoutRatio': 0.51919997,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 126.45,
#   'navPrice': None,
#   'averageDailyVolume10Day': 3651910,
#   'regularMarketPreviousClose': 126.6,
#   'fiftyDayAverage': 119.1418,
#   'trailingAnnualDividendRate': 5.95,
#   'open': 126.1,
#   'toCurrency': None,
#   'averageVolume10days': 3651910,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 5.96,
#   'exDividendDate': 1660867200,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 125.36,
#   'currency': 'USD',
#   'trailingPE': 10.976439,
#   'regularMarketVolume': 4160391,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 69529542656,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 9639340,
#   'dayLow': 125.36,
#   'ask': 127.99,
#   'askSize': 900,
#   'volume': 4160391,
#   'fiftyTwoWeekHigh': 186.3,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 3.24,
#   'fiftyTwoWeekLow': 107.07,
#   'bid': 0,
#   'tradeable': False,
#   'dividendYield': 0.0471,
#   'bidSize': 1200,
#   'dayHigh': 126.45,
#   'coinMarketCapLink': None,
#   'regularMarketPrice': 125.79,
#   'preMarketPrice': 126.12,
#   'logo_url': 'https://logo.clearbit.com/3m.com'},
#  {'zip': '10285',
#   'sector': 'Financial Services',
#   'fullTimeEmployees': 64000,
#   'longBusinessSummary': "American Express Company, together with its subsidiaries, provides charge and credit payment card products, and travel-related services worldwide. The company operates through three segments: Global Consumer Services Group, Global Commercial Services, and Global Merchant and Network Services. Its products and services include payment and financing products; network services; accounts payable expense management products and services; and travel and lifestyle services. The company's products and services also comprise merchant acquisition and processing, servicing and settlement, point-of-sale marketing, and information products and services for merchants; and fraud prevention services, as well as the design and operation of customer loyalty programs. It sells its products and services to consumers, small businesses, mid-sized companies, and large corporations through mobile and online applications, third-party vendors and business partners, direct mail, telephone, in-house sales teams, and direct response advertising. American Express Company was founded in 1850 and is headquartered in New York, New York.",
#   'city': 'New York',
#   'phone': '212 640 2000',
#   'state': 'NY',
#   'country': 'United States',
#   'companyOfficers': [],
#   'website': 'https://www.americanexpress.com',
#   'maxAge': 1,
#   'address1': '200 Vesey Street',
#   'industry': 'Credit Services',
#   'ebitdaMargins': 0,
#   'profitMargins': 0.15438,
#   'grossMargins': 0.67660004,
#   'operatingCashflow': 17654999040,
#   'revenueGrowth': 0.149,
#   'operatingMargins': 0.20771,
#   'ebitda': None,
#   'targetLowPrice': 128,
#   'recommendationKey': 'buy',
#   'grossProfits': 30799000000,
#   'freeCashflow': None,
#   'targetMedianPrice': 168.5,
#   'currentPrice': 148.45,
#   'earningsGrowth': 0.089,
#   'currentRatio': 1.623,
#   'returnOnAssets': 0.03838,
#   'numberOfAnalystOpinions': 24,
#   'targetMeanPrice': 168.38,
#   'debtToEquity': 183.726,
#   'returnOnEquity': 0.31679,
#   'targetHighPrice': 220,
#   'totalCash': 31394000896,
#   'totalDebt': 43983998976,
#   'totalRevenue': 49622999040,
#   'totalCashPerShare': 42.014,
#   'financialCurrency': 'USD',
#   'revenuePerShare': 65.639,
#   'quickRatio': 1.611,
#   'recommendationMean': 2.4,
#   'exchange': 'NYQ',
#   'shortName': 'American Express Company',
#   'longName': 'American Express Company',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EDT',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-14400000',
#   'quoteType': 'EQUITY',
#   'symbol': 'AXP',
#   'messageBoardId': 'finmb_92001',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 2.489,
#   'beta3Year': None,
#   'enterpriseToEbitda': None,
#   '52WeekChange': -0.1427499,
#   'morningStarRiskRating': None,
#   'forwardEps': 10.7,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 747233024,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 32.048,
#   'sharesShort': 6915457,
#   'sharesPercentSharesOut': 0.0093,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1640908800,
#   'heldPercentInstitutions': 0.86754,
#   'netIncomeToCommon': 7533000192,
#   'trailingEps': 9.84,
#   'lastDividendValue': 0.52,
#   'SandP52WeekChange': -0.1638366,
#   'priceToBook': 4.6321144,
#   'heldPercentInsiders': 0.00132,
#   'nextFiscalYearEnd': 1703980800,
#   'yield': None,
#   'mostRecentQuarter': 1664496000,
#   'shortRatio': 2.21,
#   'sharesShortPreviousMonthDate': 1663200000,
#   'floatShares': 594483388,
#   'beta': 1.135961,
#   'enterpriseValue': 123516690432,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1128297600,
#   'lastSplitFactor': '10000:8753',
#   'legalType': None,
#   'lastDividendDate': 1665619200,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 0.029,
#   'priceToSalesTrailing12Months': 2.2353897,
#   'dateShortInterest': 1665705600,
#   'pegRatio': 1.98,
#   'ytdReturn': None,
#   'forwardPE': 13.873832,
#   'lastCapGain': None,
#   'shortPercentOfFloat': 0.0116,
#   'sharesShortPriorMonth': 9122975,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 150.44,
#   'regularMarketOpen': 150,
#   'twoHundredDayAverage': 162.81905,
#   'trailingAnnualDividendYield': 0.013227865,
#   'payoutRatio': 0.14739999,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 150.3,
#   'navPrice': None,
#   'averageDailyVolume10Day': 4310690,
#   'regularMarketPreviousClose': 150.44,
#   'fiftyDayAverage': 147.55,
#   'trailingAnnualDividendRate': 1.99,
#   'open': 150,
#   'toCurrency': None,
#   'averageVolume10days': 4310690,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 2.08,
#   'exDividendDate': 1665619200,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 148.32,
#   'currency': 'USD',
#   'trailingPE': 15.086382,
#   'regularMarketVolume': 2832021,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 110926741504,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 3039532,
#   'dayLow': 148.32,
#   'ask': 150.66,
#   'askSize': 900,
#   'volume': 2832021,
#   'fiftyTwoWeekHigh': 199.55,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 1.34,
#   'fiftyTwoWeekLow': 130.65,
#   'bid': 0,
#   'tradeable': False,
#   'dividendYield': 0.0138,
#   'bidSize': 1000,
#   'dayHigh': 150.3,
#   'coinMarketCapLink': None,
#   'regularMarketPrice': 148.45,
#   'preMarketPrice': 150.44,
#   'logo_url': 'https://logo.clearbit.com/americanexpress.com'},
#  {'zip': '91320-1799',
#   'sector': 'Healthcare',
#   'fullTimeEmployees': 24200,
#   'longBusinessSummary': "Amgen Inc. discovers, develops, manufactures, and delivers human therapeutics worldwide. It focuses on inflammation, oncology/hematology, bone health, cardiovascular disease, nephrology, and neuroscience areas. The company's products include Enbrel to treat plaque psoriasis, rheumatoid arthritis, and psoriatic arthritis; Neulasta that reduces the chance of infection due a low white blood cell count in patients cancer; Prolia to treat postmenopausal women with osteoporosis; Xgeva for skeletal-related events prevention; Otezla for the treatment of adult patients with plaque psoriasis, psoriatic arthritis, and oral ulcers associated with Behçet's disease; Aranesp to treat a lower-than-normal number of red blood cells and anemia; KYPROLIS to treat patients with relapsed or refractory multiple myeloma; and Repatha, which reduces the risks of myocardial infarction, stroke, and coronary revascularization. It also markets Nplate, Vectibix, MVASI, Parsabiv, EPOGEN, KANJINTI, BLINCYTO, Aimovig, EVENITY, AMGEVITATM, Sensipar/Mimpara, NEUPOGEN, IMLYGIC, Corlanor, and AVSOLA. Amgen Inc. serves healthcare providers, including physicians or their clinics, dialysis centers, hospitals, and pharmacies. It distributes its products through pharmaceutical wholesale distributors, as well as direct-to-consumer channels. It has collaboration agreements with Novartis Pharma AG; UCB; Bayer HealthCare LLC; BeiGene, Ltd.; Eli Lilly and Company; Datos Health; and Verastem, Inc. to evaluate VS-6766 in combination with lumakrastm (Sotorasib) in patients with KRAS G12C-mutant non-small cell lung cancer. It has an agreement with Kyowa Kirin Co., Ltd. to jointly develop and commercialize KHK4083, a Phase 3-ready anti-OX40 fully human monoclonal antibody for the treatment of atopic dermatitis and other autoimmune diseases; and research and development collaboration with Neumora Therapeutics, Inc. and Plexium, Inc. Amgen Inc. was incorporated in 1980 and is headquartered in Thousand Oaks, California.",
#   'city': 'Thousand Oaks',
#   'phone': '805 447 1000',
#   'state': 'CA',
#   'country': 'United States',
#   'companyOfficers': [],
#   'website': 'https://www.amgen.com',
#   'maxAge': 1,
#   'address1': 'One Amgen Center Drive',
#   'fax': '805 447 1010',
#   'industry': 'Drug Manufacturers—General',
#   'ebitdaMargins': 0.49947,
#   'profitMargins': 0.24924,
#   'grossMargins': 0.7575,
#   'operatingCashflow': 9319999488,
#   'revenueGrowth': 0.01,
#   'operatingMargins': 0.37754002,
#   'ebitda': 13178000384,
#   'targetLowPrice': 182,
#   'recommendationKey': 'hold',
#   'grossProfits': 19525000000,
#   'freeCashflow': 8452874752,
#   'targetMedianPrice': 256,
#   'currentPrice': 270.35,
#   'earningsGrowth': 2.026,
#   'currentRatio': 1.531,
#   'returnOnAssets': 0.10457,
#   'numberOfAnalystOpinions': 23,
#   'targetMeanPrice': 254.85,
#   'debtToEquity': 1509.797,
#   'returnOnEquity': 1.23308,
#   'targetHighPrice': 295,
#   'totalCash': 7183000064,
#   'totalDebt': 36522000384,
#   'totalRevenue': 26383998976,
#   'totalCashPerShare': 13.428,
#   'financialCurrency': 'USD',
#   'revenuePerShare': 47.711,
#   'quickRatio': 0.991,
#   'recommendationMean': 2.7,
#   'exchange': 'NMS',
#   'shortName': 'Amgen Inc.',
#   'longName': 'Amgen Inc.',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EDT',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-14400000',
#   'quoteType': 'EQUITY',
#   'symbol': 'AMGN',
#   'messageBoardId': 'finmb_24816',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 6.663,
#   'beta3Year': None,
#   'enterpriseToEbitda': 13.341,
#   '52WeekChange': 0.2617848,
#   'morningStarRiskRating': None,
#   'forwardEps': 18.66,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 534931008,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 4.522,
#   'sharesShort': 16835371,
#   'sharesPercentSharesOut': 0.0315,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1640908800,
#   'heldPercentInstitutions': 0.79843,
#   'netIncomeToCommon': 6576000000,
#   'trailingEps': 11.76,
#   'lastDividendValue': 1.94,
#   'SandP52WeekChange': -0.1638366,
#   'priceToBook': 59.785496,
#   'heldPercentInsiders': 0.00215,
#   'nextFiscalYearEnd': 1703980800,
#   'yield': None,
#   'mostRecentQuarter': 1656547200,
#   'shortRatio': 6.57,
#   'sharesShortPreviousMonthDate': 1663200000,
#   'floatShares': 533850290,
#   'beta': 0.575165,
#   'enterpriseValue': 175808413696,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 943228800,
#   'lastSplitFactor': '2:1',
#   'legalType': None,
#   'lastDividendDate': 1660694400,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 1.838,
#   'priceToSalesTrailing12Months': 5.4812994,
#   'dateShortInterest': 1665705600,
#   'pegRatio': 2.01,
#   'ytdReturn': None,
#   'forwardPE': 14.488211,
#   'lastCapGain': None,
#   'shortPercentOfFloat': 0.0315,
#   'sharesShortPriorMonth': 16954695,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 273.81,
#   'regularMarketOpen': 269.2,
#   'twoHundredDayAverage': 240.65295,
#   'trailingAnnualDividendYield': 0.02702604,
#   'payoutRatio': 0.6293,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 271.81,
#   'navPrice': None,
#   'averageDailyVolume10Day': 2619150,
#   'regularMarketPreviousClose': 273.81,
#   'fiftyDayAverage': 241.4396,
#   'trailingAnnualDividendRate': 7.4,
#   'open': 269.2,
#   'toCurrency': None,
#   'averageVolume10days': 2619150,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 7.76,
#   'exDividendDate': 1660694400,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 268,
#   'currency': 'USD',
#   'trailingPE': 22.988945,
#   'regularMarketVolume': 3033759,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 144618602496,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 2652925,
#   'dayLow': 268,
#   'ask': 272.4,
#   'askSize': 1400,
#   'volume': 3033759,
#   'fiftyTwoWeekHigh': 274.54,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 2.82,
#   'fiftyTwoWeekLow': 198.64,
#   'bid': 269.64,
#   'tradeable': False,
#   'dividendYield': 0.028299998,
#   'bidSize': 800,
#   'dayHigh': 271.81,
#   'coinMarketCapLink': None,
#   'regularMarketPrice': 270.35,
#   'preMarketPrice': 270.57,
#   'logo_url': 'https://logo.clearbit.com/amgen.com'},
#  {'zip': '95014',
#   'sector': 'Technology',
#   'fullTimeEmployees': 164000,
#   'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. It also sells various related services. In addition, the company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. Further, it provides AppleCare support and cloud services store services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts. Additionally, the company offers various services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was incorporated in 1977 and is headquartered in Cupertino, California.',
#   'city': 'Cupertino',
#   'phone': '408 996 1010',
#   'state': 'CA',
#   'country': 'United States',
#   'companyOfficers': [],
#   'website': 'https://www.apple.com',
#   'maxAge': 1,
#   'address1': 'One Apple Park Way',
#   'industry': 'Consumer Electronics',
#   'ebitdaMargins': 0.33105,
#   'profitMargins': 0.2531,
#   'grossMargins': 0.43310001,
#   'operatingCashflow': 122151002112,
#   'revenueGrowth': 0.081,
#   'operatingMargins': 0.30289,
#   'ebitda': 130541002752,
#   'targetLowPrice': 122,
#   'recommendationKey': 'buy',
#   'grossProfits': 170782000000,
#   'freeCashflow': 90215251968,
#   'targetMedianPrice': 180,
#   'currentPrice': 153.34,
#   'earningsGrowth': 0.048,
#   'currentRatio': 0.879,
#   'returnOnAssets': 0.21214001,
#   'numberOfAnalystOpinions': 40,
#   'targetMeanPrice': 180.81,
#   'debtToEquity': 261.446,
#   'returnOnEquity': 1.75459,
#   'targetHighPrice': 214,
#   'totalCash': 48304001024,
#   'totalDebt': 132480000000,
#   'totalRevenue': 394328014848,
#   'totalCashPerShare': 3.036,
#   'financialCurrency': 'USD',
#   'revenuePerShare': 24.317,
#   'quickRatio': 0.709,
#   'recommendationMean': 1.9,
#   'exchange': 'NMS',
#   'shortName': 'Apple Inc.',
#   'longName': 'Apple Inc.',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EDT',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-14400000',
#   'quoteType': 'EQUITY',
#   'symbol': 'AAPL',
#   'messageBoardId': 'finmb_24937',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 6.4,
#   'beta3Year': None,
#   'enterpriseToEbitda': 19.331,
#   '52WeekChange': 0.02213037,
#   'morningStarRiskRating': None,
#   'forwardEps': 6.81,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 15908100096,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 3.178,
#   'sharesShort': 108664761,
#   'sharesPercentSharesOut': 0.0068,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1663977600,
#   'heldPercentInstitutions': 0.60048,
#   'netIncomeToCommon': 99802996736,
#   'trailingEps': 6.02,
#   'lastDividendValue': 0.23,
#   'SandP52WeekChange': -0.1638366,
#   'priceToBook': 48.250473,
#   'heldPercentInsiders': 0.00071000005,
#   'nextFiscalYearEnd': 1727136000,
#   'yield': None,
#   'mostRecentQuarter': 1663977600,
#   'shortRatio': 1.11,
#   'sharesShortPreviousMonthDate': 1663200000,
#   'floatShares': 15891096314,
#   'beta': 1.249815,
#   'enterpriseValue': 2523526856704,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1598832000,
#   'lastSplitFactor': '4:1',
#   'legalType': None,
#   'lastDividendDate': 1659657600,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 0.008,
#   'priceToSalesTrailing12Months': 6.1860886,
#   'dateShortInterest': 1665705600,
#   'pegRatio': 2.73,
#   'ytdReturn': None,
#   'forwardPE': 22.516886,
#   'lastCapGain': None,
#   'shortPercentOfFloat': 0.0068,
#   'sharesShortPriorMonth': 116076947,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 155.74,
#   'regularMarketOpen': 153.155,
#   'twoHundredDayAverage': 156.64845,
#   'trailingAnnualDividendYield': 0.0057788617,
#   'payoutRatio': 0.14729999,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 154.24,
#   'navPrice': None,
#   'averageDailyVolume10Day': 92247830,
#   'regularMarketPreviousClose': 155.74,
#   'fiftyDayAverage': 151.4366,
#   'trailingAnnualDividendRate': 0.9,
#   'open': 153.155,
#   'toCurrency': None,
#   'averageVolume10days': 92247830,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 0.92,
#   'exDividendDate': 1667520000,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 151.93,
#   'currency': 'USD',
#   'trailingPE': 25.47176,
#   'regularMarketVolume': 97943171,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 2439347961856,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 84286781,
#   'dayLow': 151.93,
#   'ask': 0,
#   'askSize': 800,
#   'volume': 97943171,
#   'fiftyTwoWeekHigh': 182.94,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 1.02,
#   'fiftyTwoWeekLow': 129.04,
#   'bid': 154.51,
#   'tradeable': False,
#   'dividendYield': 0.0058999998,
#   'bidSize': 1400,
#   'dayHigh': 154.24,
#   'coinMarketCapLink': None,
#   'regularMarketPrice': 153.34,
#   'preMarketPrice': 154.73,
#   'logo_url': 'https://logo.clearbit.com/apple.com'},
#  {'zip': '60606-1596',
#   'sector': 'Industrials',
#   'fullTimeEmployees': 142000,
#   'longBusinessSummary': 'The Boeing Company, together with its subsidiaries, designs, develops, manufactures, sales, services, and supports commercial jetliners, military aircraft, satellites, missile defense, human space flight and launch systems, and services worldwide. The company operates through four segments: Commercial Airplanes; Defense, Space & Security; Global Services; and Boeing Capital. The Commercial Airplanes segment provides commercial jet aircraft for passenger and cargo requirements, as well as fleet support services. The Defense, Space & Security segment engages in the research, development, production, and modification of manned and unmanned military aircraft and weapons systems; strategic defense and intelligence systems, which include strategic missile and defense systems, command, control, communications, computers, intelligence, surveillance and reconnaissance, cyber and information solutions, and intelligence systems; and satellite systems, such as government and commercial satellites, and space exploration. The Global Services segment offers products and services, including supply chain and logistics management, engineering, maintenance and modifications, upgrades and conversions, spare parts, pilot and maintenance training systems and services, technical and maintenance documents, and data analytics and digital services to commercial and defense customers. The Boeing Capital segment offers financing services and manages financing exposure for a portfolio of equipment under operating leases, sales-type/finance leases, notes and other receivables, assets held for sale or re-lease, and investments. The company was incorporated in 1916 and is based in Chicago, Illinois.',
#   'city': 'Chicago',
#   'phone': '312 544 2000',
#   'state': 'IL',
#   'country': 'United States',
#   'companyOfficers': [],
#   'website': 'https://www.boeing.com',
#   'maxAge': 1,
#   'address1': '100 North Riverside Plaza',
#   'industry': 'Aerospace & Defense',
#   'ebitdaMargins': -0.043649998,
#   'profitMargins': -0.13748,
#   'grossMargins': 0.015420001,
#   'operatingCashflow': 771000000,
#   'revenueGrowth': 0.044,
#   'operatingMargins': -0.07639,
#   'ebitda': -2680999936,
#   'targetLowPrice': None,
#   'recommendationKey': 'none',
#   'grossProfits': 5190000000,
#   'freeCashflow': 4145250048,
#   'targetMedianPrice': None,
#   'currentPrice': 142.51,
#   'earningsGrowth': None,
#   'currentRatio': 1.219,
#   'returnOnAssets': -0.02062,
#   'numberOfAnalystOpinions': None,
#   'targetMeanPrice': None,
#   'debtToEquity': None,
#   'returnOnEquity': None,
#   'targetHighPrice': None,
#   'totalCash': 14257000448,
#   'totalDebt': 57218998272,
#   'totalRevenue': 61420998656,
#   'totalCashPerShare': 23.922,
#   'financialCurrency': 'USD',
#   'revenuePerShare': 103.572,
#   'quickRatio': 0.295,
#   'recommendationMean': None,
#   'exchange': 'NYQ',
#   'shortName': 'Boeing Company (The)',
#   'longName': 'The Boeing Company',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EDT',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-14400000',
#   'quoteType': 'EQUITY',
#   'symbol': 'BA',
#   'messageBoardId': 'finmb_370857',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 2.096,
#   'beta3Year': None,
#   'enterpriseToEbitda': -48.024,
#   '52WeekChange': -0.33021575,
#   'morningStarRiskRating': None,
#   'forwardEps': 2.23,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 595982976,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': -29.715,
#   'sharesShort': 9201409,
#   'sharesPercentSharesOut': 0.0155,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1640908800,
#   'heldPercentInstitutions': 0.50483,
#   'netIncomeToCommon': -8444000256,
#   'trailingEps': -8.285,
#   'lastDividendValue': 2.055,
#   'SandP52WeekChange': -0.1638366,
#   'priceToBook': None,
#   'heldPercentInsiders': 0.00104,
#   'nextFiscalYearEnd': 1703980800,
#   'yield': None,
#   'mostRecentQuarter': 1664496000,
#   'shortRatio': 1.25,
#   'sharesShortPreviousMonthDate': 1663200000,
#   'floatShares': 551415569,
#   'beta': 1.419675,
#   'enterpriseValue': 128752222208,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 865814400,
#   'lastSplitFactor': '2:1',
#   'legalType': None,
#   'lastDividendDate': 1581552000,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': None,
#   'priceToSalesTrailing12Months': 1.3828094,
#   'dateShortInterest': 1665705600,
#   'pegRatio': -0.91,
#   'ytdReturn': None,
#   'forwardPE': 63.905827,
#   'lastCapGain': None,
#   'shortPercentOfFloat': 0.0155,
#   'sharesShortPriorMonth': 9629027,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 143.84,
#   'regularMarketOpen': 141.88,
#   'twoHundredDayAverage': 161.6628,
#   'trailingAnnualDividendYield': 0,
#   'payoutRatio': 0,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 144.449,
#   'navPrice': None,
#   'averageDailyVolume10Day': 9124100,
#   'regularMarketPreviousClose': 143.84,
#   'fiftyDayAverage': 143.5136,
#   'trailingAnnualDividendRate': 0,
#   'open': 141.88,
#   'toCurrency': None,
#   'averageVolume10days': 9124100,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': None,
#   'exDividendDate': 1581552000,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 139.52,
#   'currency': 'USD',
#   'regularMarketVolume': 5981146,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 84933533696,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 6942010,
#   'dayLow': 139.52,
#   'ask': 144.72,
#   'askSize': 1100,
#   'volume': 5981146,
#   'fiftyTwoWeekHigh': 233.94,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': None,
#   'fiftyTwoWeekLow': 113.02,
#   'bid': 143.52,
#   'tradeable': False,
#   'dividendYield': None,
#   'bidSize': 1200,
#   'dayHigh': 144.449,
#   'coinMarketCapLink': None,
#   'regularMarketPrice': 142.51,
#   'preMarketPrice': 144,
#   'logo_url': 'https://logo.clearbit.com/boeing.com'},
#  {'zip': '60015',
#   'sector': 'Industrials',
#   'fullTimeEmployees': 107700,
#   'longBusinessSummary': "Caterpillar Inc. manufactures and sells construction and mining equipment, diesel and natural gas engines, and industrial gas turbines worldwide. Its Construction Industries segment offers asphalt pavers, backhoe loaders, compactors, cold planers, compact track and multi-terrain loaders, excavators, motorgraders, pipelayers, road reclaimers, site prep tractors, skid steer loaders, telehandlers, and utility vehicles; mini, small, medium, and large excavators; compact, small, and medium wheel loaders; track-type tractors and loaders; and wheel excavators. The Resource Industries segment provides electric rope shovels, draglines, hydraulic shovels, rotary drills, hard rock vehicles, track-type tractors, mining trucks, longwall miners, wheel loaders, off-highway trucks, articulated trucks, wheel tractor scrapers, wheel dozers, fleet management, landfill compactors, soil compactors, machinery components, autonomous ready vehicles and solutions, select work tools, and safety services and mining performance solutions. The Energy & Transportation segment offers reciprocating engines, generator sets, integrated systems and solutions, turbines and turbine-related services, remanufactured reciprocating engines and components, centrifugal gas compressors, diesel-electric locomotives and components, and other rail-related products and services for marine, oil and gas, industrial, and electric power generation sectors. The company's Financial Products segment provides operating and finance leases, installment sale contracts, working capital loans, and wholesale financing plans; and insurance and risk management products for vehicles, power generation facilities, and marine vessels. The All Other operating segment manufactures filters and fluids, undercarriage, ground engaging tools, etc. The company was formerly known as Caterpillar Tractor Co. and changed its name to Caterpillar Inc. in 1986. The company was founded in 1925 and is headquartered in Deerfield, Illinois.",
#   'city': 'Deerfield',
#   'phone': '224-551-4000',
#   'state': 'IL',
#   'country': 'United States',
#   'companyOfficers': [],
#   'website': 'https://www.caterpillar.com',
#   'maxAge': 1,
#   'address1': '510 Lake Cook Road',
#   'industry': 'Farm & Heavy Construction Machinery',
#   'address2': 'Suite 100',
#   'ebitdaMargins': 0.19974001,
#   'profitMargins': 0.13017,
#   'grossMargins': 0.25634,
#   'operatingCashflow': 6439000064,
#   'revenueGrowth': 0.209,
#   'operatingMargins': 0.16156,
#   'ebitda': 11310999552,
#   'targetLowPrice': 174,
#   'recommendationKey': 'hold',
#   'grossProfits': 13189000000,
#   'freeCashflow': 5446374912,
#   'targetMedianPrice': 219.5,
#   'currentPrice': 216.46,
#   'earningsGrowth': 0.488,
#   'currentRatio': 1.41,
#   'returnOnAssets': 0.07073,
#   'numberOfAnalystOpinions': 24,
#   'targetMeanPrice': 219.08,
#   'debtToEquity': 233.805,
#   'returnOnEquity': 0.45611,
#   'targetHighPrice': 260,
#   'totalCash': 5402999808,
#   'totalDebt': 36524998656,
#   'totalRevenue': 56627998720,
#   'totalCashPerShare': 10.291,
#   'financialCurrency': 'USD',
#   'revenuePerShare': 106.399,
#   'quickRatio': 0.776,
#   'recommendationMean': 2.6,
#   'exchange': 'NYQ',
#   'shortName': 'Caterpillar, Inc.',
#   'longName': 'Caterpillar Inc.',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EDT',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-14400000',
#   'quoteType': 'EQUITY',
#   'symbol': 'CAT',
#   'messageBoardId': 'finmb_259378',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 2.584,
#   'beta3Year': None,
#   'enterpriseToEbitda': 12.935,
#   '52WeekChange': 0.04509461,
#   'morningStarRiskRating': None,
#   'forwardEps': 14.59,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 527908992,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 29.697,
#   'sharesShort': 5538906,
#   'sharesPercentSharesOut': 0.0105,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1640908800,
#   'heldPercentInstitutions': 0.71059,
#   'netIncomeToCommon': 7370999808,
#   'trailingEps': 13.74,
#   'lastDividendValue': 1.2,
#   'SandP52WeekChange': -0.1638366,
#   'priceToBook': 7.288952,
#   'heldPercentInsiders': 0.00227,
#   'nextFiscalYearEnd': 1703980800,
#   'yield': None,
#   'mostRecentQuarter': 1664496000,
#   'shortRatio': 1.79,
#   'sharesShortPreviousMonthDate': 1663200000,
#   'floatShares': 523776750,
#   'beta': 1.013264,
#   'enterpriseValue': 146306498560,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1121299200,
#   'lastSplitFactor': '2:1',
#   'legalType': None,
#   'lastDividendDate': 1666310400,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 0.431,
#   'priceToSalesTrailing12Months': 2.0179272,
#   'dateShortInterest': 1665705600,
#   'pegRatio': 1.24,
#   'ytdReturn': None,
#   'forwardPE': 14.836189,
#   'lastCapGain': None,
#   'shortPercentOfFloat': 0.0105,
#   'sharesShortPriorMonth': 5643831,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 219.34,
#   'regularMarketOpen': 215.34,
#   'twoHundredDayAverage': 198.5657,
#   'trailingAnnualDividendYield': 0.02106319,
#   'payoutRatio': 0.32970002,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 218.8688,
#   'navPrice': None,
#   'averageDailyVolume10Day': 3702850,
#   'regularMarketPreviousClose': 219.34,
#   'fiftyDayAverage': 183.6632,
#   'trailingAnnualDividendRate': 4.62,
#   'open': 215.34,
#   'toCurrency': None,
#   'averageVolume10days': 3702850,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 4.8,
#   'exDividendDate': 1666310400,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 215.01,
#   'currency': 'USD',
#   'trailingPE': 15.754004,
#   'regularMarketVolume': 3615783,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 114271182848,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 2896687,
#   'dayLow': 215.01,
#   'ask': 218.9,
#   'askSize': 800,
#   'volume': 3615783,
#   'fiftyTwoWeekHigh': 237.9,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 2.43,
#   'fiftyTwoWeekLow': 160.6,
#   'bid': 215.71,
#   'tradeable': False,
#   'dividendYield': 0.0219,
#   'bidSize': 900,
#   'dayHigh': 218.8688,
#   'coinMarketCapLink': None,
#   'regularMarketPrice': 216.46,
#   'preMarketPrice': 217.95,
#   'logo_url': 'https://logo.clearbit.com/caterpillar.com'},
#  {'zip': '94583-2324',
#   'sector': 'Energy',
#   'fullTimeEmployees': 42595,
#   'longBusinessSummary': 'Chevron Corporation, through its subsidiaries, engages in integrated energy and chemicals operations worldwide. The company operates in two segments, Upstream and Downstream. The Upstream segment is involved in the exploration, development, production, and transportation of crude oil and natural gas; processing, liquefaction, transportation, and regasification associated with liquefied natural gas; transportation of crude oil through pipelines; and transportation, storage, and marketing of natural gas, as well as operates a gas-to-liquids plant. The Downstream segment engages in refining crude oil into petroleum products; marketing crude oil, refined products, and lubricants; manufacturing and marketing of renewable fuels; transporting crude oil and refined products by pipeline, marine vessel, motor equipment, and rail car; and manufacturing and marketing of commodity petrochemicals, plastics for industrial uses, and fuel and lubricant additives. It is also involved in the cash management and debt financing activities; insurance operations; real estate activities; and technology businesses. The company was formerly known as ChevronTexaco Corporation and changed its name to Chevron Corporation in 2005. Chevron Corporation was founded in 1879 and is based in San Ramon, California.',
#   'city': 'San Ramon',
#   'phone': '925 842 1000',
#   'state': 'CA',
#   'country': 'United States',
#   'companyOfficers': [],
#   'website': 'https://www.chevron.com',
#   'maxAge': 1,
#   'address1': '6001 Bollinger Canyon Road',
#   'industry': 'Oil & Gas Integrated',
#   'ebitdaMargins': 0.23324,
#   'profitMargins': 0.15048,
#   'grossMargins': 0.39185002,
#   'operatingCashflow': 46586998784,
#   'revenueGrowth': 0.492,
#   'operatingMargins': 0.16258,
#   'ebitda': 52958998528,
#   'targetLowPrice': 143,
#   'recommendationKey': 'buy',
#   'grossProfits': 66234000000,
#   'freeCashflow': None,
#   'targetMedianPrice': 190,
#   'currentPrice': 180.9,
#   'earningsGrowth': 0.814,
#   'currentRatio': None,
#   'returnOnAssets': None,
#   'numberOfAnalystOpinions': 27,
#   'targetMeanPrice': 187.26,
#   'debtToEquity': 16.974,
#   'returnOnEquity': None,
#   'targetHighPrice': 215,
#   'totalCash': 12369999872,
#   'totalDebt': 26235000832,
#   'totalRevenue': 227054993408,
#   'totalCashPerShare': 6.319,
#   'financialCurrency': 'USD',
#   'revenuePerShare': 117.477,
#   'quickRatio': None,
#   'recommendationMean': 2.3,
#   'exchange': 'NYQ',
#   'shortName': 'Chevron Corporation',
#   'longName': 'Chevron Corporation',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EDT',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-14400000',
#   'quoteType': 'EQUITY',
#   'symbol': 'CVX',
#   'messageBoardId': 'finmb_98506',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 1.617,
#   'beta3Year': None,
#   'enterpriseToEbitda': 6.933,
#   '52WeekChange': 0.58921194,
#   'morningStarRiskRating': None,
#   'forwardEps': 16.7,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 1957430016,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 78.447,
#   'sharesShort': 17618537,
#   'sharesPercentSharesOut': 0.009,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1640908800,
#   'heldPercentInstitutions': 0.71576,
#   'netIncomeToCommon': 34166999040,
#   'trailingEps': 14.99,
#   'lastDividendValue': 1.42,
#   'SandP52WeekChange': -0.1638366,
#   'priceToBook': 2.3060155,
#   'heldPercentInsiders': 0.0008,
#   'nextFiscalYearEnd': 1703980800,
#   'yield': None,
#   'mostRecentQuarter': 1664496000,
#   'shortRatio': 1.7,
#   'sharesShortPreviousMonthDate': 1663200000,
#   'floatShares': 1794302197,
#   'beta': 1.129697,
#   'enterpriseValue': 367172124672,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1095033600,
#   'lastSplitFactor': '2:1',
#   'legalType': None,
#   'lastDividendDate': 1660780800,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 0.838,
#   'priceToSalesTrailing12Months': 1.55953,
#   'dateShortInterest': 1665705600,
#   'pegRatio': 0.66,
#   'ytdReturn': None,
#   'forwardPE': 10.8323345,
#   'lastCapGain': None,
#   'shortPercentOfFloat': 0.009,
#   'sharesShortPriorMonth': 23372393,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 179.98,
#   'regularMarketOpen': 178.06,
#   'twoHundredDayAverage': 156.33575,
#   'trailingAnnualDividendYield': 0.031114569,
#   'payoutRatio': 0.3682,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 183.84,
#   'navPrice': None,
#   'averageDailyVolume10Day': 8661870,
#   'regularMarketPreviousClose': 179.98,
#   'fiftyDayAverage': 160.1216,
#   'trailingAnnualDividendRate': 5.6,
#   'open': 178.06,
#   'toCurrency': None,
#   'averageVolume10days': 8661870,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 5.68,
#   'exDividendDate': 1668643200,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 178.06,
#   'currency': 'USD',
#   'trailingPE': 12.068046,
#   'regularMarketVolume': 12919061,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 354099068928,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 9049445,
#   'dayLow': 178.06,
#   'ask': 183.67,
#   'askSize': 900,
#   'volume': 12919061,
#   'fiftyTwoWeekHigh': 183.84,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 4.43,
#   'fiftyTwoWeekLow': 110.73,
#   'bid': 182.4,
#   'tradeable': False,
#   'dividendYield': 0.031600002,
#   'bidSize': 900,
#   'dayHigh': 183.84,
#   'coinMarketCapLink': None,
#   'regularMarketPrice': 180.9,
#   'preMarketPrice': 183.41,
#   'logo_url': 'https://logo.clearbit.com/chevron.com'},
#  {'zip': '95134-1706',
#   'sector': 'Technology',
#   'fullTimeEmployees': 83300,
#   'longBusinessSummary': 'Cisco Systems, Inc. designs, manufactures, and sells Internet Protocol based networking and other products related to the communications and information technology industry in the Americas, Europe, the Middle East, Africa, the Asia Pacific, Japan, and China. The company also offers switching portfolio encompasses campus switching as well as data center switching; enterprise routing portfolio interconnects public and private wireline and mobile networks, delivering highly secure, and reliable connectivity to campus, data center and branch networks; wireless products include wireless access points that are standalone, controller appliance-based, switch-converged, and Meraki cloud-managed offerings; and compute portfolio including the cisco unified computing system, hyperflex, and software management capabilities, which combine computing, networking, and storage infrastructure management and virtualization. In addition, it provides Internet for the future product consists of routed optical networking, 5G, silicon, and optics solutions; collaboration products, such as meetings, collaboration devices, calling, contact center, and communication platform as a service; end-to-end security product consists of network security, cloud security, security endpoints, unified threat management, and zero trust; and optimized application experiences products including full stack observability and cloud-native platform. Further, the company offers a range of service and support options for its customers, including technical support and advanced services and advisory services. It serves businesses of various sizes, public institutions, governments, and service providers. The company sells its products and services directly, as well as through systems integrators, service providers, other resellers, and distributors. Cisco Systems, Inc. has strategic alliances with other companies. Cisco Systems, Inc. was incorporated in 1984 and is headquartered in San Jose, California.',
#   'city': 'San Jose',
#   'phone': '408 526 4000',
#   'state': 'CA',
#   'country': 'United States',
#   'companyOfficers': [],
#   'website': 'https://www.cisco.com',
#   'maxAge': 1,
#   'address1': '170 West Tasman Drive',
#   'industry': 'Communication Equipment',
#   'ebitdaMargins': 0.30843002,
#   'profitMargins': 0.2291,
#   'grossMargins': 0.62548,
#   'operatingCashflow': 13226000384,
#   'revenueGrowth': -0.002,
#   'operatingMargins': 0.27203,
#   'ebitda': 15902000128,
#   'targetLowPrice': 44,
#   'recommendationKey': 'buy',
#   'grossProfits': 32248000000,
#   'freeCashflow': 9768625152,
#   'targetMedianPrice': 52.5,
#   'currentPrice': 45.43,
#   'earningsGrowth': -0.039,
#   'currentRatio': 1.432,
#   'returnOnAssets': 0.09155,
#   'numberOfAnalystOpinions': 22,
#   'targetMeanPrice': 54.82,
#   'debtToEquity': 26.553,
#   'returnOnEquity': 0.29148,
#   'targetHighPrice': 73,
#   'totalCash': 19267000320,
#   'totalDebt': 10561000448,
#   'totalRevenue': 51556999168,
#   'totalCashPerShare': 4.689,
#   'financialCurrency': 'USD',
#   'revenuePerShare': 12.364,
#   'quickRatio': 1.162,
#   'recommendationMean': 2.5,
#   'exchange': 'NMS',
#   'shortName': 'Cisco Systems, Inc.',
#   'longName': 'Cisco Systems, Inc.',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EDT',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-14400000',
#   'quoteType': 'EQUITY',
#   'symbol': 'CSCO',
#   'messageBoardId': 'finmb_19691',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 3.452,
#   'beta3Year': None,
#   'enterpriseToEbitda': 11.191,
#   '52WeekChange': -0.21155846,
#   'morningStarRiskRating': None,
#   'forwardEps': 3.8,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 4105969920,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 9.677,
#   'sharesShort': 38391572,
#   'sharesPercentSharesOut': 0.0094,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1659139200,
#   'heldPercentInstitutions': 0.75005996,
#   'netIncomeToCommon': 11811999744,
#   'trailingEps': 2.81,
#   'lastDividendValue': 0.38,
#   'SandP52WeekChange': -0.1638366,
#   'priceToBook': 4.694637,
#   'heldPercentInsiders': 0.00090000004,
#   'nextFiscalYearEnd': 1722297600,
#   'yield': None,
#   'mostRecentQuarter': 1659139200,
#   'shortRatio': 1.88,
#   'sharesShortPreviousMonthDate': 1663200000,
#   'floatShares': 4105885799,
#   'beta': 0.951731,
#   'enterpriseValue': 177958797312,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 953769600,
#   'lastSplitFactor': '2:1',
#   'legalType': None,
#   'lastDividendDate': 1664841600,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': -0.064,
#   'priceToSalesTrailing12Months': 3.6180193,
#   'dateShortInterest': 1665705600,
#   'pegRatio': 1.92,
#   'ytdReturn': None,
#   'forwardPE': 11.955263,
#   'lastCapGain': None,
#   'shortPercentOfFloat': 0.0094,
#   'sharesShortPriorMonth': 38247511,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 45.64,
#   'regularMarketOpen': 45.305,
#   'twoHundredDayAverage': 48.22335,
#   'trailingAnnualDividendYield': 0.032865908,
#   'payoutRatio': 0.5319,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 45.635,
#   'navPrice': None,
#   'averageDailyVolume10Day': 19103280,
#   'regularMarketPreviousClose': 45.64,
#   'fiftyDayAverage': 43.1714,
#   'trailingAnnualDividendRate': 1.5,
#   'open': 45.305,
#   'toCurrency': None,
#   'averageVolume10days': 19103280,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 1.52,
#   'exDividendDate': 1664841600,
# ...
#   'debtToEquity': 63.095,
#   'returnOnEquity': 0.40883,
#   'targetHighPrice': 290,
#   'totalCash': 18521999360,
#   'totalDebt': 22449999872,
#   'totalRevenue': 29309999104,
#   'totalCashPerShare': 9.647,
#   'financialCurrency': 'USD',
#   'revenuePerShare': 15.139,
#   'quickRatio': 1.078,
#   'recommendationMean': 1.8,
#   'exchange': 'NYQ',
#   'shortName': 'Visa Inc.',
#   'longName': 'Visa Inc.',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EDT',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-14400000',
#   'quoteType': 'EQUITY',
#   'symbol': 'V',
#   'messageBoardId': 'finmb_38043467',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 13.926,
#   'beta3Year': None,
#   'enterpriseToEbitda': 19.871,
#   '52WeekChange': -0.009467363,
#   'morningStarRiskRating': None,
#   'forwardEps': 9.65,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 1635010048,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 17.321,
#   'sharesShort': 41439394,
#   'sharesPercentSharesOut': 0.0197,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1664496000,
#   'heldPercentInstitutions': 0.97608,
#   'netIncomeToCommon': 14956999680,
#   'trailingEps': 7,
#   'lastDividendValue': 0.375,
#   'SandP52WeekChange': -0.1638366,
#   'priceToBook': 11.96005,
#   'heldPercentInsiders': 0.0018000001,
#   'nextFiscalYearEnd': 1727654400,
#   'yield': None,
#   'mostRecentQuarter': 1664496000,
#   'shortRatio': 5.63,
#   'sharesShortPreviousMonthDate': 1663200000,
#   'floatShares': 1633171187,
#   'beta': 0.916359,
#   'enterpriseValue': 408184782848,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 1426723200,
#   'lastSplitFactor': '4:1',
#   'legalType': None,
#   'lastDividendDate': 1660176000,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 0.099,
#   'priceToSalesTrailing12Months': 14.889157,
#   'dateShortInterest': 1665705600,
#   'pegRatio': 1.49,
#   'ytdReturn': None,
#   'forwardPE': 21.46736,
#   'lastCapGain': None,
#   'shortPercentOfFloat': 0.0254,
#   'sharesShortPriorMonth': 45344195,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 209.34,
#   'regularMarketOpen': 208.92,
#   'twoHundredDayAverage': 206.32774,
#   'trailingAnnualDividendYield': 0.007523646,
#   'payoutRatio': 0.2143,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 209.62,
#   'navPrice': None,
#   'averageDailyVolume10Day': 8314500,
#   'regularMarketPreviousClose': 209.34,
#   'fiftyDayAverage': 192.9726,
#   'trailingAnnualDividendRate': 1.575,
#   'open': 208.92,
#   'toCurrency': None,
#   'averageVolume10days': 8314500,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 1.8,
#   'exDividendDate': 1667952000,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 206.2,
#   'currency': 'USD',
#   'trailingPE': 29.594286,
#   'regularMarketVolume': 8446323,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 436401176576,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 6649585,
#   'dayLow': 206.2,
#   'ask': 209,
#   'askSize': 800,
#   'volume': 8446323,
#   'fiftyTwoWeekHigh': 235.85,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 0.6,
#   'fiftyTwoWeekLow': 174.6,
#   'bid': 208.44,
#   'tradeable': False,
#   'dividendYield': 0.0086,
#   'bidSize': 900,
#   'dayHigh': 209.62,
#   'coinMarketCapLink': None,
#   'regularMarketPrice': 207.16,
#   'preMarketPrice': 208.7,
#   'logo_url': 'https://logo.clearbit.com/usa.visa.com'},
#  {'zip': '60015',
#   'sector': 'Healthcare',
#   'fullTimeEmployees': 200000,
#   'longBusinessSummary': 'Walgreens Boots Alliance, Inc. operates as an integrated healthcare, pharmacy, and retailer in the United States (U.S.), the United Kingdom, Germany, and internationally. It operates through three segments: U.S. Retail Pharmacy, International, and U.S. Healthcare. The U.S. Retail Pharmacy segment sells prescription drugs and an assortment of retail products, including health, wellness, beauty, personal care, consumable, and general merchandise products through its retail drugstores. It also provides health and wellness, and specialty and home delivery pharmacy services. As of August 31, 2022, this segment operated 8,886 retail stores under the Walgreens and Duane Reade brands in the United States; and 3 specialty pharmacies. The International segment sells prescription drugs; and health and wellness, beauty, personal care, and other consumer products through its pharmacy-led health and beauty retail stores and optical practices, as well as through boots.com and an integrated mobile application. It also engages in pharmaceutical wholesaling and distribution business in Germany. As of August 31, 2022, this segment operated 3,989 retail stores under the Boots, Benavides, and Ahumada brands in the United Kingdom, Thailand, the Republic of Ireland, and Chile; and 543 optical practices, including 160 on a franchise basis. The U.S. Healthcare segment provides value-based primary care services; post-acute and home care management services; and clinical healthcare services. It also operates as a specialty pharmacy integrator and accelerator for hospitals. As of August 31, 2022, this segment operated 334 VillageMD clinics, including 146 co-located clinics, 124 standalone clinics, and 64 affiliate clinics. Walgreens Boots Alliance, Inc. was founded in 1901 and is based in Deerfield, Illinois.',
#   'city': 'Deerfield',
#   'phone': '847 315 3700',
#   'state': 'IL',
#   'country': 'United States',
#   'companyOfficers': [],
#   'website': 'https://www.walgreensbootsalliance.com',
#   'maxAge': 1,
#   'address1': '108 Wilmot Road',
#   'industry': 'Pharmaceutical Retailers',
#   'ebitdaMargins': 0.03579,
#   'profitMargins': 0.032679997,
#   'grossMargins': 0.213,
#   'operatingCashflow': 3899000064,
#   'revenueGrowth': -0.053,
#   'operatingMargins': 0.0231,
#   'ebitda': 4749000192,
#   'targetLowPrice': 32,
#   'recommendationKey': 'hold',
#   'grossProfits': 28266000000,
#   'freeCashflow': 3260750080,
#   'targetMedianPrice': 38.1,
#   'currentPrice': 36.5,
#   'earningsGrowth': None,
#   'currentRatio': 0.748,
#   'returnOnAssets': 0.02236,
#   'numberOfAnalystOpinions': 15,
#   'targetMeanPrice': 38.67,
#   'debtToEquity': 119.748,
#   'returnOnEquity': 0.14904,
#   'targetHighPrice': 45,
#   'totalCash': 2484000000,
#   'totalDebt': 36413001728,
#   'totalRevenue': 132703002624,
#   'totalCashPerShare': 2.872,
#   'financialCurrency': 'USD',
#   'revenuePerShare': 153.52,
#   'quickRatio': 0.332,
#   'recommendationMean': 3.1,
#   'exchange': 'NMS',
#   'shortName': 'Walgreens Boots Alliance, Inc.',
#   'longName': 'Walgreens Boots Alliance, Inc.',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EDT',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-14400000',
#   'quoteType': 'EQUITY',
#   'symbol': 'WBA',
#   'messageBoardId': 'finmb_93624',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 0.532,
#   'beta3Year': None,
#   'enterpriseToEbitda': 14.872,
#   '52WeekChange': -0.23560208,
#   'morningStarRiskRating': None,
#   'forwardEps': 4.77,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 864812992,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 29.232,
#   'sharesShort': 25491041,
#   'sharesPercentSharesOut': 0.0295,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1661904000,
#   'heldPercentInstitutions': 0.59497,
#   'netIncomeToCommon': 4336999936,
#   'trailingEps': 5,
#   'lastDividendValue': 0.48,
#   'SandP52WeekChange': -0.1638366,
#   'priceToBook': 1.2486316,
#   'heldPercentInsiders': 0.17354,
#   'nextFiscalYearEnd': 1725062400,
#   'yield': None,
#   'mostRecentQuarter': 1661904000,
#   'shortRatio': 3.1,
#   'sharesShortPreviousMonthDate': 1663200000,
#   'floatShares': 715113945,
#   'beta': 0.654753,
#   'enterpriseValue': 70627680256,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 919123200,
#   'lastSplitFactor': '2:1',
#   'legalType': None,
#   'lastDividendDate': 1660780800,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': None,
#   'priceToSalesTrailing12Months': 0.23786707,
#   'dateShortInterest': 1665705600,
#   'pegRatio': 6.34,
#   'ytdReturn': None,
#   'forwardPE': 7.651992,
#   'lastCapGain': None,
#   'shortPercentOfFloat': 0.0355,
#   'sharesShortPriorMonth': 22566220,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 36.58,
#   'regularMarketOpen': 36.525,
#   'twoHundredDayAverage': 41.54555,
#   'trailingAnnualDividendYield': 0.052296333,
#   'payoutRatio': 0.38169998,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 36.805,
#   'navPrice': None,
#   'averageDailyVolume10Day': 7672850,
#   'regularMarketPreviousClose': 36.58,
#   'fiftyDayAverage': 34.2986,
#   'trailingAnnualDividendRate': 1.913,
#   'open': 36.525,
#   'toCurrency': None,
#   'averageVolume10days': 7672850,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 1.92,
#   'exDividendDate': 1668384000,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 36.24,
#   'currency': 'USD',
#   'trailingPE': 7.3,
#   'regularMarketVolume': 9705822,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 31565674496,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 7666645,
#   'dayLow': 36.24,
#   'ask': 37,
#   'askSize': 1000,
#   'volume': 9705822,
#   'fiftyTwoWeekHigh': 55,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 3.54,
#   'fiftyTwoWeekLow': 30.39,
#   'bid': 36.05,
#   'tradeable': False,
#   'dividendYield': 0.0525,
#   'bidSize': 1400,
#   'dayHigh': 36.805,
#   'coinMarketCapLink': None,
#   'regularMarketPrice': 36.5,
#   'preMarketPrice': 36.5,
#   'logo_url': 'https://logo.clearbit.com/walgreensbootsalliance.com'},
#  {'zip': '72716',
#   'sector': 'Consumer Defensive',
#   'fullTimeEmployees': 2300000,
#   'longBusinessSummary': "Walmart Inc. engages in the operation of retail, wholesale, and other units worldwide. The company operates through three segments: Walmart U.S., Walmart International, and Sam's Club. It operates supercenters, supermarkets, hypermarkets, warehouse clubs, cash and carry stores, and discount stores; membership-only warehouse clubs; ecommerce websites, such as walmart.com, walmart.com.mx, walmart.ca, flipkart.com, and samsclub.com; and mobile commerce applications. The company offers grocery and consumables, which includes dairy, meat, bakery, deli, produce, dry, chilled or frozen packaged foods, alcoholic and nonalcoholic beverages, floral, snack foods, candy, other grocery items, health and beauty aids, paper goods, laundry and home care, baby care, pet supplies, and other consumable items; and health and wellness products covering pharmacy, over-the-counter drugs and other medical products, and optical and hearing services. It also provides gasoline stations and tobacco; home improvement, outdoor living, gardening, furniture, apparel, jewelry, tools and power equipment, housewares, toys, seasonal items, mattresses, and tire and battery centers; and consumer electronics and accessories, software, video games, office supplies, appliances, and third-party gift cards. In addition, the company offers fuel and financial services and related products, including money orders, prepaid cards, money transfers, and check cashing and bill payment, as well as various types of installment lending. It operates approximately 10,500 stores and various e-commerce websites under 46 banners in 24 countries. The company was formerly known as Wal-Mart Stores, Inc. and changed its name to Walmart Inc. in February 2018. The company was founded in 1945 and is based in Bentonville, Arkansas.",
#   'city': 'Bentonville',
#   'phone': '479 273 4000',
#   'state': 'AR',
#   'country': 'United States',
#   'companyOfficers': [],
#   'website': 'https://www.stock.walmart.com',
#   'maxAge': 1,
#   'address1': '702 South West 8th Street',
#   'industry': 'Discount Stores',
#   'ebitdaMargins': 0.05884,
#   'profitMargins': 0.023599999,
#   'grossMargins': 0.24598,
#   'operatingCashflow': 20998000640,
#   'revenueGrowth': 0.084,
#   'operatingMargins': 0.04058,
#   'ebitda': 34586001408,
#   'targetLowPrice': 130,
#   'recommendationKey': 'buy',
#   'grossProfits': 143754000000,
#   'freeCashflow': 301500000,
#   'targetMedianPrice': 155,
#   'currentPrice': 142.33,
#   'earningsGrowth': 0.237,
#   'currentRatio': 0.842,
#   'returnOnAssets': 0.06138,
#   'numberOfAnalystOpinions': 36,
#   'targetMeanPrice': 152.94,
#   'debtToEquity': 78.288,
#   'returnOnEquity': 0.16205,
#   'targetHighPrice': 170,
#   'totalCash': 13923000320,
#   'totalDebt': 67207999488,
#   'totalRevenue': 587823972352,
#   'totalCashPerShare': 5.13,
#   'financialCurrency': 'USD',
#   'revenuePerShare': 212.903,
#   'quickRatio': 0.215,
#   'recommendationMean': 2,
#   'exchange': 'NYQ',
#   'shortName': 'Walmart Inc.',
#   'longName': 'Walmart Inc.',
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EDT',
#   'isEsgPopulated': False,
#   'gmtOffSetMilliseconds': '-14400000',
#   'quoteType': 'EQUITY',
#   'symbol': 'WMT',
#   'messageBoardId': 'finmb_313055',
#   'market': 'us_market',
#   'annualHoldingsTurnover': None,
#   'enterpriseToRevenue': 0.763,
#   'beta3Year': None,
#   'enterpriseToEbitda': 12.964,
#   '52WeekChange': -0.049358785,
#   'morningStarRiskRating': None,
#   'forwardEps': 6.58,
#   'revenueQuarterlyGrowth': None,
#   'sharesOutstanding': 2714240000,
#   'fundInceptionDate': None,
#   'annualReportExpenseRatio': None,
#   'totalAssets': None,
#   'bookValue': 28.497,
#   'sharesShort': 11766385,
#   'sharesPercentSharesOut': 0.0043,
#   'fundFamily': None,
#   'lastFiscalYearEnd': 1643587200,
#   'heldPercentInstitutions': 0.32783002,
#   'netIncomeToCommon': 13870000128,
#   'trailingEps': 5,
#   'lastDividendValue': 0.56,
#   'SandP52WeekChange': -0.1638366,
#   'priceToBook': 4.9945607,
#   'heldPercentInsiders': 0.48395002,
#   'nextFiscalYearEnd': 1706659200,
#   'yield': None,
#   'mostRecentQuarter': 1659225600,
#   'shortRatio': 1.85,
#   'sharesShortPreviousMonthDate': 1663200000,
#   'floatShares': 1405839539,
#   'beta': 0.506263,
#   'enterpriseValue': 448369033216,
#   'priceHint': 2,
#   'threeYearAverageReturn': None,
#   'lastSplitDate': 924566400,
#   'lastSplitFactor': '2:1',
#   'legalType': None,
#   'lastDividendDate': 1660176000,
#   'morningStarOverallRating': None,
#   'earningsQuarterlyGrowth': 0.204,
#   'priceToSalesTrailing12Months': 0.65719974,
#   'dateShortInterest': 1665705600,
#   'pegRatio': 4.03,
#   'ytdReturn': None,
#   'forwardPE': 21.6307,
#   'lastCapGain': None,
#   'shortPercentOfFloat': 0.0084,
#   'sharesShortPriorMonth': 15335591,
#   'impliedSharesOutstanding': 0,
#   'category': None,
#   'fiveYearAverageReturn': None,
#   'previousClose': 142.51,
#   'regularMarketOpen': 142.34,
#   'twoHundredDayAverage': 136.2778,
#   'trailingAnnualDividendYield': 0.015577855,
#   'payoutRatio': 0.444,
#   'volume24Hr': None,
#   'regularMarketDayHigh': 143.07,
#   'navPrice': None,
#   'averageDailyVolume10Day': 5550030,
#   'regularMarketPreviousClose': 142.51,
#   'fiftyDayAverage': 134.164,
#   'trailingAnnualDividendRate': 2.22,
#   'open': 142.34,
#   'toCurrency': None,
#   'averageVolume10days': 5550030,
#   'expireDate': None,
#   'algorithm': None,
#   'dividendRate': 2.24,
#   'exDividendDate': 1670457600,
#   'circulatingSupply': None,
#   'startDate': None,
#   'regularMarketDayLow': 141.77,
#   'currency': 'USD',
#   'trailingPE': 28.466,
#   'regularMarketVolume': 7435678,
#   'lastMarket': None,
#   'maxSupply': None,
#   'openInterest': None,
#   'marketCap': 386317778944,
#   'volumeAllCurrencies': None,
#   'strikePrice': None,
#   'averageVolume': 7113604,
#   'dayLow': 141.77,
#   'ask': 0,
#   'askSize': 900,
#   'volume': 7435678,
#   'fiftyTwoWeekHigh': 160.77,
#   'fromCurrency': None,
#   'fiveYearAvgDividendYield': 1.83,
#   'fiftyTwoWeekLow': 117.27,
#   'bid': 142.32,
#   'tradeable': False,
#   'dividendYield': 0.015700001,
#   'bidSize': 900,
#   'dayHigh': 143.07,
#   'coinMarketCapLink': None,
#   'regularMarketPrice': 142.33,
#   'preMarketPrice': 142.53,
#   'logo_url': 'https://logo.clearbit.com/stock.walmart.com'}]

# %%
df = pd.DataFrame(infos)

# %%
df = df.drop(columns="companyOfficers")

# %%
df.to_sql("Fundamental_data", engine, index=False)
# Out:
# 30

# %%
pd.read_sql("Fundamental_data", engine)
# Out:
#            zip                  sector  fullTimeEmployees  \
# 0   55144-1000             Industrials            95000.0
# 1        10285      Financial Services            64000.0
# 2   91320-1799              Healthcare            24200.0
# 3        95014              Technology           164000.0
# 4   60606-1596             Industrials           142000.0
# 5        60015             Industrials           107700.0
# 6   94583-2324                  Energy            42595.0
# 7   95134-1706              Technology            83300.0
# 8        30313      Consumer Defensive            79000.0
# 9        91521  Communication Services           152000.0
# 10       48674         Basic Materials            35700.0
# 11       10282      Financial Services            49100.0
# 12       30339       Consumer Cyclical           500000.0
# 13       28202             Industrials            99000.0
# 14       10504              Technology           282100.0
# 15  95054-1549              Technology           121100.0
# 16       08933              Healthcare           141700.0
# 17       10179      Financial Services           288474.0
# 18       60607       Consumer Cyclical           100000.0
# 19       07033              Healthcare            67000.0
# 20  98052-6399              Technology           221000.0
# 21  97005-6453       Consumer Cyclical            79100.0
# 22       45202      Consumer Defensive           106000.0
# 23       94105              Technology            78634.0
# 24       10017      Financial Services            30184.0
# 25       55343              Healthcare           350000.0
# 26       10036  Communication Services           119500.0
# 27  94128-8999      Financial Services                NaN
# 28       60015              Healthcare           200000.0
# 29       72716      Consumer Defensive          2300000.0
#
#                                   longBusinessSummary           city  \
# 0   3M Company operates as a diversified technolog...     Saint Paul
# 1   American Express Company, together with its su...       New York
# 2   Amgen Inc. discovers, develops, manufactures, ...  Thousand Oaks
# 3   Apple Inc. designs, manufactures, and markets ...      Cupertino
# 4   The Boeing Company, together with its subsidia...        Chicago
# 5   Caterpillar Inc. manufactures and sells constr...      Deerfield
# 6   Chevron Corporation, through its subsidiaries,...      San Ramon
# 7   Cisco Systems, Inc. designs, manufactures, and...       San Jose
# 8   The Coca-Cola Company, a beverage company, man...        Atlanta
# 9   The Walt Disney Company, together with its sub...        Burbank
# 10  Dow Inc. provides various materials science so...        Midland
# 11  The Goldman Sachs Group, Inc., a financial ins...       New York
# 12  The Home Depot, Inc. operates as a home improv...        Atlanta
# 13  Honeywell International Inc. operates as a div...      Charlotte
# 14  International Business Machines Corporation pr...         Armonk
# 15  Intel Corporation engages in the design, manuf...    Santa Clara
# 16  Johnson & Johnson, together with its subsidiar...  New Brunswick
# 17  JPMorgan Chase & Co. operates as a financial s...       New York
# 18  McDonald's Corporation operates and franchises...        Chicago
# 19  Merck & Co., Inc. operates as a healthcare com...     Kenilworth
# 20  Microsoft Corporation develops, licenses, and ...        Redmond
# 21  NIKE, Inc., together with its subsidiaries, de...      Beaverton
# 22  The Procter & Gamble Company provides branded ...     Cincinnati
# 23  Salesforce, Inc. provides customer relationshi...  San Francisco
# 24  The Travelers Companies, Inc., through its sub...       New York
# 25  UnitedHealth Group Incorporated operates as a ...     Minnetonka
# 26  Verizon Communications Inc., through its subsi...       New York
# 27  Visa Inc. operates as a payments technology co...  San Francisco
# 28  Walgreens Boots Alliance, Inc. operates as an ...      Deerfield
# 29  Walmart Inc. engages in the operation of retai...    Bentonville
#
#            phone state        country                                 website  \
# 0   651 733 1110    MN  United States                      https://www.3m.com
# 1   212 640 2000    NY  United States         https://www.americanexpress.com
# 2   805 447 1000    CA  United States                   https://www.amgen.com
# 3   408 996 1010    CA  United States                   https://www.apple.com
# 4   312 544 2000    IL  United States                  https://www.boeing.com
# 5   224-551-4000    IL  United States             https://www.caterpillar.com
# 6   925 842 1000    CA  United States                 https://www.chevron.com
# 7   408 526 4000    CA  United States                   https://www.cisco.com
# 8   404 676 2121    GA  United States        https://www.coca-colacompany.com
# 9   818 560 1000    CA  United States    https://www.thewaltdisneycompany.com
# 10  989 636 1000    MI  United States                     https://www.dow.com
# 11  212-902-1000    NY  United States            https://www.goldmansachs.com
# 12  770 433 8211    GA  United States               https://www.homedepot.com
# 13  704 627 6200    NC  United States               https://www.honeywell.com
# 14  914 499 1900    NY  United States                     https://www.ibm.com
# 15  408 765 8080    CA  United States                   https://www.intel.com
# 16  732 524 0400    NJ  United States                     https://www.jnj.com
# 17  212 270 6000    NY  United States           https://www.jpmorganchase.com
# 18  630 623 3000    IL  United States         https://corporate.mcdonalds.com
# 19  908 740 4000    NJ  United States                   https://www.merck.com
# 20  425 882 8080    WA  United States               https://www.microsoft.com
# 21  503 671 6453    OR  United States              https://investors.nike.com
# 22  513 983 1100    OH  United States              https://www.pginvestor.com
# 23  415 901 7000    CA  United States              https://www.salesforce.com
# 24  917 778 6000    NY  United States               https://www.travelers.com
# 25  952 936 1300    MN  United States       https://www.unitedhealthgroup.com
# 26  212 395 1000    NY  United States                 https://www.verizon.com
# 27  650 432 3200    CA  United States                    https://usa.visa.com
# 28  847 315 3700    IL  United States  https://www.walgreensbootsalliance.com
# 29  479 273 4000    AR  United States           https://www.stock.walmart.com
#
#     maxAge  ... tradeable dividendYield  bidSize   dayHigh  coinMarketCapLink  \
# 0        1  ...     False        0.0471     1200  126.4500               None
# 1        1  ...     False        0.0138     1000  150.3000               None
# 2        1  ...     False        0.0283      800  271.8100               None
# 3        1  ...     False        0.0059     1400  154.2400               None
# 4        1  ...     False           NaN     1200  144.4490               None
# 5        1  ...     False        0.0219      900  218.8688               None
# 6        1  ...     False        0.0316      900  183.8400               None
# 7        1  ...     False        0.0333     1400   45.6350               None
# 8        1  ...     False        0.0290     1000   60.5700               None
# 9        1  ...     False           NaN     1000  106.9000               None
# 10       1  ...     False        0.0588     1100   47.8215               None
# 11       1  ...     False        0.0293      800  346.1800               None
# 12       1  ...     False        0.0254     1000  299.2800               None
# 13       1  ...     False        0.0201      800  204.9900               None
# 14       1  ...     False        0.0476     1200  138.7699               None
# 15       1  ...     False        0.0502     1800   29.1800               None
# 16       1  ...     False        0.0258      900  175.1600               None
# 17       1  ...     False        0.0317     2200  127.4300               None
# 18       1  ...     False        0.0221     1400  273.6300               None
# 19       1  ...     False        0.0274     1200  101.3550               None
# 20       1  ...     False        0.0115     1100  234.9200               None
# 21       1  ...     False        0.0130      800   93.8900               None
# 22       1  ...     False        0.0270     1000  135.6700               None
# 23       1  ...     False           NaN      900  164.0000               None
# 24       1  ...     False        0.0204      800  185.1050               None
# 25       1  ...     False        0.0120     1100  558.1000               None
# 26       1  ...     False        0.0693      800   37.5400               None
# 27       1  ...     False        0.0086      900  209.6200               None
# 28       1  ...     False        0.0525     1400   36.8050               None
# 29       1  ...     False        0.0157      900  143.0700               None
#
#     regularMarketPrice  preMarketPrice  \
# 0               125.79          126.12
# 1               148.45          150.44
# 2               270.35          270.57
# 3               153.34          154.73
# 4               142.51          144.00
# 5               216.46          217.95
# 6               180.90          183.41
# 7                45.43           45.70
# 8                59.85           60.17
# 9               106.54          107.39
# 10               46.74           47.37
# 11              344.51          346.71
# 12              296.13          299.00
# 13              204.02          205.20
# 14              138.29          139.11
# 15               28.43           28.70
# 16              173.97          174.43
# 17              125.88          126.75
# 18              272.66          273.25
# 19              101.20          101.50
# 20              232.13          234.47
# 21               92.68           93.60
# 22              134.67          135.16
# 23              162.59          164.03
# 24              184.46             NaN
# 25              555.15          558.00
# 26               37.37           37.68
# 27              207.16          208.70
# 28               36.50           36.50
# 29              142.33          142.53
#
#                                              logo_url           fax  \
# 0                    https://logo.clearbit.com/3m.com          None
# 1       https://logo.clearbit.com/americanexpress.com          None
# 2                 https://logo.clearbit.com/amgen.com  805 447 1010
# 3                 https://logo.clearbit.com/apple.com          None
# 4                https://logo.clearbit.com/boeing.com          None
# 5           https://logo.clearbit.com/caterpillar.com          None
# 6               https://logo.clearbit.com/chevron.com          None
# 7                 https://logo.clearbit.com/cisco.com          None
# 8      https://logo.clearbit.com/coca-colacompany.com          None
# 9   https://logo.clearbit.com/thewaltdisneycompany...          None
# 10                  https://logo.clearbit.com/dow.com  989 832 1456
# 11         https://logo.clearbit.com/goldmansachs.com          None
# 12            https://logo.clearbit.com/homedepot.com          None
# 13            https://logo.clearbit.com/honeywell.com          None
# 14                  https://logo.clearbit.com/ibm.com          None
# 15                https://logo.clearbit.com/intel.com          None
# 16                  https://logo.clearbit.com/jnj.com          None
# 17        https://logo.clearbit.com/jpmorganchase.com          None
# 18  https://logo.clearbit.com/corporate.mcdonalds.com          None
# 19                https://logo.clearbit.com/merck.com          None
# 20            https://logo.clearbit.com/microsoft.com  425 706 7329
# 21       https://logo.clearbit.com/investors.nike.com          None
# 22           https://logo.clearbit.com/pginvestor.com          None
# 23           https://logo.clearbit.com/salesforce.com  415 901 7040
# 24            https://logo.clearbit.com/travelers.com          None
# 25    https://logo.clearbit.com/unitedhealthgroup.com          None
# 26              https://logo.clearbit.com/verizon.com          None
# 27             https://logo.clearbit.com/usa.visa.com          None
# 28  https://logo.clearbit.com/walgreensbootsallian...          None
# 29        https://logo.clearbit.com/stock.walmart.com          None
#
#                         address2
# 0                           None
# 1                           None
# 2                           None
# 3                           None
# 4                           None
# 5                      Suite 100
# 6                           None
# 7                           None
# 8                           None
# 9                           None
# 10                          None
# 11                          None
# 12                          None
# 13                          None
# 14                          None
# 15                          None
# 16                          None
# 17                          None
# 18                          None
# 19                          None
# 20                          None
# 21                          None
# 22                          None
# 23  3rd Floor 415 Mission Street
# 24                          None
# 25           9900 Bren Road East
# 26                          None
# 27                          None
# 28                          None
# 29                          None
#
# [30 rows x 154 columns]
